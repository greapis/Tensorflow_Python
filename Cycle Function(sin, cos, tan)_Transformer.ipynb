# %% [markdown]
# <a href="https://colab.research.google.com/github/greapis/Python_practice/blob/main/Cycle%20Function(sin%2C%20cos%2C%20tan)_Transformer.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt

# x 값 생성 (-2π부터 2π까지 1000개의 점)
x = np.linspace(-2 * np.pi, 2 * np.pi, 1000)

# y 값 계산
y_sin = np.sin(x)
y_cos = np.cos(x)
y_tan = np.tan(x)

# 그래프 그리기
plt.figure(figsize=(12, 8))

# 사인 함수 그래프
plt.subplot(3, 1, 1)
plt.plot(x, y_sin, label='sin(x)', color='blue')
plt.title('Sine Function')
plt.axhline(0, color='black', linewidth=0.5, linestyle='--')
plt.axvline(0, color='black', linewidth=0.5, linestyle='--')
plt.grid(True)
plt.legend()

# 코사인 함수 그래프
plt.subplot(3, 1, 2)
plt.plot(x, y_cos, label='cos(x)', color='orange')
plt.title('Cosine Function')
plt.axhline(0, color='black', linewidth=0.5, linestyle='--')
plt.axvline(0, color='black', linewidth=0.5, linestyle='--')
plt.grid(True)
plt.legend()

# 탄젠트 함수 그래프
plt.subplot(3, 1, 3)
plt.plot(x, y_tan, label='tan(x)', color='green')
plt.title('Tangent Function')
plt.axhline(0, color='black', linewidth=0.5, linestyle='--')
plt.axvline(0, color='black', linewidth=0.5, linestyle='--')
plt.ylim(-10, 10)  # 탄젠트 함수의 발산을 제한
plt.grid(True)
plt.legend()

# 전체 레이아웃 조정 및 표시
plt.tight_layout()
plt.show()
